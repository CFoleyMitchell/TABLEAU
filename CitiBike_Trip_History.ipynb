# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# # Pull in multiple CSV files in one swoop - this never returned data - too much I think!
# import glob, os
# path = r'C:\Users\cfole\Desktop\KUBootCamp\19-Tableau\19-SOLVED_Tableau\Homework\Instructions\Resources\Import\TripHistory'
# df = pd.concat(map(pd.read_csv, glob.glob(os.path.join('', "*.csv"))))
# df.head()

# %%
# 2018 Files to Load
nyc201801 = "Resources/Import/TripHistory/201801-citibike-tripdata.csv"
nyc201802 = "Resources/Import/TripHistory/201802-citibike-tripdata.csv"
nyc201803 = "Resources/Import/TripHistory/201803-citibike-tripdata.csv"
nyc201804 = "Resources/Import/TripHistory/201804-citibike-tripdata.csv"
nyc201805 = "Resources/Import/TripHistory/201805-citibike-tripdata.csv"
nyc201806 = "Resources/Import/TripHistory/201806-citibike-tripdata.csv"
nyc201807 = "Resources/Import/TripHistory/201807-citibike-tripdata.csv"
nyc201808 = "Resources/Import/TripHistory/201808-citibike-tripdata.csv"
nyc201809 = "Resources/Import/TripHistory/201809-citibike-tripdata.csv"
nyc201810 = "Resources/Import/TripHistory/201810-citibike-tripdata.csv"
nyc201811 = "Resources/Import/TripHistory/201811-citibike-tripdata.csv"
nyc201812 = "Resources/Import/TripHistory/201812-citibike-tripdata.csv"

jc201801 = "Resources/Import/TripHistory/JC-201801-citibike-tripdata.csv"
jc201802 = "Resources/Import/TripHistory/JC-201802-citibike-tripdata.csv"
jc201803 = "Resources/Import/TripHistory/JC-201803-citibike-tripdata.csv"
jc201804 = "Resources/Import/TripHistory/JC-201804-citibike-tripdata.csv"
jc201805 = "Resources/Import/TripHistory/JC-201805-citibike-tripdata.csv"
jc201806 = "Resources/Import/TripHistory/JC-201806-citibike-tripdata.csv"
jc201807 = "Resources/Import/TripHistory/JC-201807-citibike-tripdata.csv"
jc201808 = "Resources/Import/TripHistory/JC-201808-citibike-tripdata.csv"
jc201809 = "Resources/Import/TripHistory/JC-201809-citibike-tripdata.csv"
jc201810 = "Resources/Import/TripHistory/JC-201810-citibike-tripdata.csv"
jc201811 = "Resources/Import/TripHistory/JC-201811-citibike-tripdata.csv"
jc201812 = "Resources/Import/TripHistory/JC-201812-citibike-tripdata.csv"

# Read 2018 files and store into data frame
df_n201801 = pd.read_csv(nyc201801)
df_n201802 = pd.read_csv(nyc201802)
df_n201803 = pd.read_csv(nyc201803)
df_n201804 = pd.read_csv(nyc201804)
df_n201805 = pd.read_csv(nyc201805)
df_n201806 = pd.read_csv(nyc201806)
df_n201807 = pd.read_csv(nyc201807)
df_n201808 = pd.read_csv(nyc201808)
df_n201809 = pd.read_csv(nyc201809)
df_n201810 = pd.read_csv(nyc201810)
df_n201811 = pd.read_csv(nyc201811)
df_n201812 = pd.read_csv(nyc201812)

df_j201801 = pd.read_csv(jc201801)
df_j201802 = pd.read_csv(jc201802)
df_j201803 = pd.read_csv(jc201803)
df_j201804 = pd.read_csv(jc201804)
df_j201805 = pd.read_csv(jc201805)
df_j201806 = pd.read_csv(jc201806)
df_j201807 = pd.read_csv(jc201807)
df_j201808 = pd.read_csv(jc201808)
df_j201809 = pd.read_csv(jc201809)
df_j201810 = pd.read_csv(jc201810)
df_j201811 = pd.read_csv(jc201811)
df_j201812 = pd.read_csv(jc201812)

# Append 2018 files and store in dataframe
df_18 = df_n201801.append(df_n201802, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201803, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201804, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201805, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201806, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201807, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201808, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201809, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201810, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201811, ignore_index=True, sort=True)
df_18 = df_18.append(df_n201812, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201801, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201802, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201803, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201804, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201805, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201806, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201807, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201808, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201809, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201810, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201811, ignore_index=True, sort=True)
df_18 = df_18.append(df_j201812, ignore_index=True, sort=True)

# Save 2018 CSV File
df_18.to_csv("Resources/Export_BikeTrips/2018_citibike_trips.csv")

# Display 2018 Head
df_18.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   31956        1992           505.0             40.749013
# 1   32536        1969          3255.0             40.750585
# 2   16069        1956           525.0             40.755942
# 3   31781        1974           447.0             40.763707
# 4   30319        1992          3356.0             40.774667
#
#    end station longitude         end station name  gender  start station id  \
# 0             -73.988484          6 Ave & W 33 St       1              72.0
# 1             -73.994685          8 Ave & W 31 St       1              72.0
# 2             -74.002116         W 34 St & 11 Ave       1              72.0
# 3             -73.985162          8 Ave & W 52 St       1              72.0
# 4             -73.984706  Amsterdam Ave & W 66 St       1              72.0
#
#    start station latitude  start station longitude start station name  \
# 0               40.767272               -73.993929   W 52 St & 11 Ave
# ...
